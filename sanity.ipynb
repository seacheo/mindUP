# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

data=pickle.load(open('pickled-avg/OpenBCISession_2020-02-14_11-09-00-SEVEN', 'rb'))

# %%
data[200][19]
# Out:
# {'bpm': 103.68663594470047,
#  'ibi': 578.6666666666666,
#  'sdnn': 167.25154517994554,
#  'sdsd': 93.4528335512917,
#  'rmssd': 148.2700239428051,
#  'pnn20': 0.8888888888888888,
#  'pnn50': 0.5555555555555556,
#  'hr_mad': 104.0,
#  'sd1': 98.64514279745792,
#  'sd2': 196.35115934920722,
#  's': 60849.78504646676,
#  'sd1/sd2': 0.5023914456344981,
#  'breathingrate': 0.24687294272547727}

# %%
data=np.transpose(data)

# %%
plt.figure(figsize=(25,10), dpi=250)
plt.plot(data[10])

# %%
def hasNan(nl):
    for thing in nl:
        if type(thing) is list:
            if hasNan(thing):
                return True
        if thing != thing:
            return True
    return False

# %%
hasNan(data)
# Out:
# False
