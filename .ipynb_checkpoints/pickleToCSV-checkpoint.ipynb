# %%
import pickle
import os
import numpy, scipy.io
from multiprocessing import Pool

# %%
baseFolder='./pickled-avg'
outFolder='./converted'
files=[f for f in os.listdir(baseFolder) if not f.startswith('.')]

# %%
files
# Out:
# ['OpenBCISession_2020-03-06_10-28-17-LUKE',
#  'OpenBCISession_2020-02-07_10-42-36-FOUR.2',
#  'OpenBCISession_2020-02-23_16-49-310-VIR',
#  'OpenBCISession_2020-02-06_12-08-05-THREE',
#  'OpenBCISession_2020-02-29_17-51-57-BAHAR',
#  'OpenBCISession_2020-02-07_11-12-39-FIVE',
#  'OpenBCISession_2020-02-14_11-09-00-SEVEN',
#  'OpenBCISession_2020-02-10_10-55-19=ONE.2',
#  'OpenBCISession_2020-02-29_17-19-28-ELI',
#  'OpenBCISession_2020-02-14_11-43-46-EIGHT',
#  'OpenBCISession_2020-02-23_18-14-52-ISH',
#  'OpenBCISession_2020-02-07_12-09-54-SIX',
#  'OpenBCISession_2020-02-06_11-26-48-TWO']

# %%
for file in files:
#     [data]=pickle.load(open('pickled-avg/'+file, 'rb'))
    scipy.io.savemat(outFolder+'/'+file, mdict={'data': pickle.load(open('pickled-avg/'+file, 'rb'))})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-3483f70393d4> in <module>
#       1 for file in files:
#       2 #     [data]=pickle.load(open('pickled-avg/'+file, 'rb'))
# ----> 3     scipy.io.savemat(outFolder+'/'+file, mdict={'data': pickle.load(open('pickled-avg/'+file, 'rb'))})
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/io/matlab/mio.py in savemat(file_name, mdict, appendmat, format, long_field_names, do_compression, oned_as)
#     277         else:
#     278             raise ValueError("Format should be '4' or '5'")
# --> 279         MW.put_variables(mdict)
#     280
#     281
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/io/matlab/mio5.py in put_variables(self, mdict, write_header)
#     847                 self.file_stream.write(out_str)
#     848             else:  # not compressing
# --> 849                 self._matrix_writer.write_top(var, asbytes(name), is_global)
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/io/matlab/mio5.py in write_top(self, arr, name, is_global)
#     588         self._var_name = name
#     589         # write the header and data
# --> 590         self.write(arr)
#     591
#     592     def write(self, arr):
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/io/matlab/mio5.py in write(self, arr)
#     619             self.write_struct(narr)
#     620         elif narr.dtype.hasobject:  # cell array
# --> 621             self.write_cells(narr)
#     622         elif narr.dtype.kind in ('U', 'S'):
#     623             if self.unicode_strings:
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/io/matlab/mio5.py in write_cells(self, arr)
#     724         A = np.atleast_2d(arr).flatten('F')
#     725         for el in A:
# --> 726             self.write(el)
#     727
#     728     def write_empty_struct(self):
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/io/matlab/mio5.py in write(self, arr)
#     609         if narr is None:
#     610             raise TypeError('Could not convert %s (type %s) to array'
# --> 611                             % (arr, type(arr)))
#     612         if isinstance(narr, MatlabObject):
#     613             self.write_object(narr)
#
# TypeError: Could not convert 1900-01-01 10:29:37.406000 (type <class 'datetime.datetime'>) to array

# %%
name=files[0]
def convert(name):
    data=pickle.load(open('pickled-avg/'+name, 'rb'))
    f=open(outFolder+'/'+name+'.csv', 'w')

    f.write('useless,Fp1, Fp2, C3, C4, P7, P8, O1, O2, F7, F8, F3, F4, T7, T8, P3, P4,rawHR,time,bpm, ibi,sdnn,sdsd,rmssd,pnn20,pnn50,hr_mad,sd1,sd2,s,sd1/sd2,breathingrate,lf,hf,lf/hf,start,end,block\n')
    for elem in data:
        f.write(', '.join(str(x) for x in elem[0:18]))
        f.write(', '+str(elem[18].hour)+':'+str(elem[18].minute)+':'+str(elem[18].second)+'.'+str(int(elem[18].microsecond/1000)))

        f.write(', ')
        f.write(', '.join(str(x) for x in list(elem[19].values())[0:-1]))
        f.write(', ')

        f.write(str(list(elem[19].values())[-1][0])+', '+str(list(elem[19].values())[-1][1]))
        f.write(', ')
        f.write(elem[20]+'\n')
    f.close()

# %%
p = Pool(len(files))
p.map(convert, files)
